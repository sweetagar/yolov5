# %% [markdown]
# # Initilize

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Roboflow Install (May need to RESTART RUNTIME!)

# %%
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.3 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=e1f6ea1b422450c3248e8fb1eaa6835f199caada28b9b90f64708c0671ea7f3e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
# ...

# %%
# %cd /content/drive/MyDrive/yolo_datasets/

from roboflow import Roboflow
rf = Roboflow(api_key="Mum5BZkuNVt9U4HTkKPA")
project = rf.workspace("trial-kbztl").project("test_tf_reduced")
dataset = project.version(1).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to test_tf_reduced-1 in yolov5pytorch:: 100%|██████████| 5946/5946 [00:01<00:00, 3267.61it/s]

# %% [markdown]
# Insall YOLO5

# %%
# !git   # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %% [markdown]
# System Check

# %%
import tensorflow as tf
device_list = tf.test.gpu_device_name()
print(device_list)
# Out:
# /device:GPU:0

# %%
# !cp -rf /content/drive/MyDrive/yolo_datasets/Toddler-final-6 /content/yolov5/Toddler-final-6

# %% [markdown]
# Untilities

# %%
# !unzip -q /content/drive/MyDrive/yolo_datasets/toddler_finalv6.zip -d /content/drive/MyDrive/yolo_datasets/

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           screen  # screenshot
#                           path/  # directory
#                          'path/*.jpg'  # glob
#                          'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                          'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights runs/train/exp10/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/yolo_datasets/funny_baby_check.mp4

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)

# %% [markdown]
# # 3. Train

# %%
# !pip install roboflow

# %% [markdown]
# Roboflow Dataset **Download**

# %%
# %cd /content/drive/MyDrive/yolo_datasets/
from roboflow import Roboflow
rf = Roboflow(api_key="Mum5BZkuNVt9U4HTkKPA")
project = rf.workspace("trial-kbztl").project("test_01-fcyqp")
dataset = project.version(3).download("yolov5")
# %cd /content/yolov5
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to test_01-3 in yolov5pytorch:: 100%|██████████| 694/694 [00:00<00:00, 2110.30it/s]

# %% [markdown]
# Sample

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache

# %% [markdown]
# My Training

# %%
# Train my own custom data for 200 epochs
# !python train.py --img 640 --batch 2 --epochs 100 --data /content/yolov5/test_tf_reduced-1/data.yaml --weights yolov5s.pt --cache --project /content/drive/MyDrive/yolo_datasets/test_tf_reduced-1/train_results/
# Out:
# train: weights=/content/drive/MyDrive/yolo_datasets/test_02-2/train_results/test_02-2_200epochs.pt, cfg=, data=/content/yolov5/test_02-3/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=/content/drive/MyDrive/yolo_datasets/test_02-3/train_results/test_02-2_200plus100/, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-178-ga199480 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# Train my own custom data for 300 epochs
# !python train.py --img 640 --batch 4 --epochs 10 --data /content/drive/MyDrive/yolo_datasets/test_02-2/data.yaml --weights yolov5s.pt --cache --project /content/drive/MyDrive/yolo_datasets/test_02-2/train_results

# %%
# !cp /content/yolov5/runs/train/exp/weights/last.pt /content/drive/MyDrive/yolo_datasets/test_2-2_200epochs.pt

# %%
# !cp -rf /content/yolov5/runs/train/exp /content/drive/MyDrive/yolo_datasets/train_results/test_2-2_200epochs
